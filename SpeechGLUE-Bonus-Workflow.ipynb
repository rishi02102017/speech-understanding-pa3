# %% [markdown]
# #  DoRA Fine-Tuning and Evaluation Notebook
# This notebook contains the full workflow for the **Bonus Question** of Speech Understanding Assignment 3.
#
# We:
# - Reproduce results from the SpeechGLUE paper on SST-2 and MRPC
# - Fine-tune a DoRA-based model on SNIPS (intent classification)
# - Transfer the encoder to SST-2 and MRPC using new classifier heads

# %%
# !pip install datasets transformers gtts torchaudio librosa pandas scikit-learn --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 44.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 31.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 29.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 85.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 16.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 16.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.12.0 which is incompatible.

# %%
from datasets import load_dataset

sst2 = load_dataset("glue", "sst2")
mrpc = load_dataset("glue", "mrpc")

snips = load_dataset("sonos-nlu-benchmark/snips_built_in_intents")

print("SST-2:", sst2['train'][0])
print("MRPC:", mrpc['train'][0])
print("SNIPS:", snips['train'][0])
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/35.3k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/3.11M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/72.8k [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/148k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/67349 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/872 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1821 [00:00<?, ? examples/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/649k [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/75.7k [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/308k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/3668 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/408 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1725 [00:00<?, ? examples/s]
# README.md:   0%|          | 0.00/6.65k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/11.2k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/328 [00:00<?, ? examples/s]
# SST-2: {'sentence': 'hide new secretions from the parental units ', 'label': 0, 'idx': 0}
# MRPC: {'sentence1': 'Amrozi accused his brother , whom he called " the witness " , of deliberately distorting his evidence .', 'sentence2': 'Referring to him as only " the witness " , Amrozi accused his brother of deliberately distorting his evidence .', 'label': 1, 'idx': 0}
# SNIPS: {'text': "Share my location with Hillary's sister", 'label': 5}

# %% [markdown]
# ##  Step 1: Convert Text to Speech with gTTS
# We use Google TTS to synthesize audio files from the text of SST-2, MRPC, and SNIPS.

# %%
from gtts import gTTS
import os
from pathlib import Path
import pandas as pd
import re
from time import sleep

def clean_text(text):
    text = text.replace("’", "'").replace("‘", "'")
    text = text.replace("Jo's", "Jo")
    text = text.replace("Airbnb", "your stay")
    text = re.sub(r"[^a-zA-Z0-9\s\.\?\!]", "", text)
    return text.strip()

def safe_tts(text, path, retries=3):
    for attempt in range(retries):
        try:
            tts = gTTS(text)
            tts.save(path)
            return True
        except Exception as e:
            print(f"Retry {attempt+1} failed for: {text} -> {e}")
            sleep(1)
    return False

def generate_audio(dataset, field, label_field, output_dir, max_samples=None):
    Path(output_dir).mkdir(parents=True, exist_ok=True)
    records = []
    for i, sample in enumerate(dataset):
        if max_samples and i >= max_samples:
            break
        raw_text = sample[field]
        text = clean_text(raw_text)
        label = sample[label_field]
        filename = f"{i}.wav"
        path = os.path.join(output_dir, filename)

        if safe_tts(text, path):
            records.append({"path": path, "label": label})
            print(f" Saved: {text}")
        else:
            print(f" Failed completely for: {text}")

    return pd.DataFrame(records)

df_sst2 = generate_audio(sst2['train'], 'sentence', 'label', 'audio_sst2', 500)
df_mrpc = generate_audio(mrpc['train'], 'sentence1', 'label', 'audio_mrpc', 500)
df_snips = generate_audio(snips['train'], 'text', 'label', 'audio_snips', 328)

df_sst2.to_csv("metadata_sst2.csv", index=False)
df_mrpc.to_csv("metadata_mrpc.csv", index=False)
df_snips.to_csv("metadata_snips.csv", index=False)
# Out:
#  Saved: hide new secretions from the parental units
#  Saved: contains no wit  only labored gags
#  Saved: that loves its characters and communicates something rather beautiful about human nature
#  Saved: remains utterly satisfied to remain the same throughout
#  Saved: on the worst revengeofthenerds clichs the filmmakers could dredge up
#  Saved: that s far too tragic to merit such superficial treatment
#  Saved: demonstrates that the director of such hollywood blockbusters as patriot games can still turn out a small  personal film with an emotional wallop .
#  Saved: of saucy
#  Saved: a depressed fifteenyearold s suicidal poetry
#  Saved: are more deeply thought through than in most  rightthinking  films
#  Saved: goes to absurd lengths
#  Saved: for those moviegoers who complain that  they do nt make movies like they used to anymore
#  Saved: the part where nothing s happening
#  Saved: saw how bad this movie was
#  Saved: lend some dignity to a dumb story
#  Saved: the greatest musicians
#  Saved: cold movie
#  Saved: with his usual intelligence and subtlety
#  Saved: redundant concept
#  Saved: swimming is above all about a young woman s face  and by casting an actress whose face projects that woman s doubts and yearnings  it succeeds .
#  Saved: equals the original and in some ways even betters it
#  Saved: if anything  see it for karen black  who camps up a storm as a fringe feminist conspiracy theorist named dirty dick .
#  Saved: a smile on your face
#  Saved: comes from the brave  uninhibited performances
#  Saved: excruciatingly unfunny and pitifully unromantic
#  Saved: enriched by an imaginatively mixed cast of antic spirits
#  Saved: which half of dragonfly is worse  the part where nothing s happening  or the part where something s happening
#  Saved: in world cinema
#  Saved: very good viewing alternative
#  Saved: the plot is nothing but boilerplate clichs from start to finish
#  Saved: the action is stilted
#  Saved: on all cylinders
#  Saved: will find little of interest in this film  which is often preachy and poorly acted
#  Saved: by far the worst movie of the year
#  Saved: sit through
#  Saved: more than another  best man  clone by weaving a theme throughout this funny film
#  Saved: it s about issues most adults have to face in marriage and i think that s what i liked about it  the real issues tucked between the silly and crude storyline
#  Saved: heroes
#  Saved: oblivious to the existence of this film
#  Saved: sharply
#  Saved: the entire point of a shaggy dog story  of course  is that it goes nowhere  and this is classic nowheresville in every sense .
#  Saved: sometimes dry
#  Saved: as they come  already having been recycled more times than i d care to count
#  Saved: covers this territory with wit and originality  suggesting that with his fourth feature
#  Saved: a  40 million version of a game
#  Saved: gorgeous and deceptively minimalist
#  Saved: cross swords with the best of them and
#  Saved: as a fringe feminist conspiracy theorist
#  Saved: proves once again he has nt lost his touch  bringing off a superb performance in an admittedly middling film .
#  Saved: disappointments
#  Saved: the horrors
#  Saved: a muddle splashed with bloody beauty as vivid as any scorsese has ever given us .
#  Saved: many pointless
#  Saved: a beautifully
#  Saved: contrived  wellworn situations
#  Saved: a doa
#  Saved: poor ben bratt could nt find stardom if mapquest emailed him pointtopoint driving directions .
#  Saved: to be as subtle and touching as the son s room
#  Saved: starts with a legend
#  Saved: far less sophisticated and
#  Saved: rich veins of funny stuff in this movie
#  Saved: no apparent joy
#  Saved: shot on ugly digital video
#  Saved: ... a sour little movie at its core  an exploration of the emptiness that underlay the relentless gaiety of the 1920 s ... the film s ending has a  what was it all for ?
#  Saved: though ford and neeson capably hold our interest  but its just not a thrilling movie
#  Saved: is pretty damned funny .
#  Saved: we never feel anything for these characters
#  Saved: s a lousy one at that
#  Saved: the corporate circus that is the recording industry in the current climate of mergers and downsizing
#  Saved: the storylines are woven together skilfully  the magnificent swooping aerial shots are breathtaking  and the overall experience is awesome .
#  Saved: of the most highlypraised disappointments i
#  Saved: sounds like a cruel deception carried out by men of marginal intelligence  with reactionary ideas about women and a total lack of empathy .
#  Saved: seem fresh
#  Saved: to the dustbin of history
#  Saved: as a director  eastwood is off his game
#  Saved: pays earnest homage to turntablists
#  Saved: weak and
#  Saved: skip this dreck
#  Saved: contains very few laughs and even less surprises
#  Saved: film to affirm love s power to help people endure almost unimaginable horror
#  Saved: are an absolute joy
#  Saved: generates
#  Saved: like life  is nt much fun without the highs and lows
#  Saved: based on a true and historically significant story
#  Saved: wellrounded tribute
#  Saved: though many of the actors throw off a spark or two when they first appear  they ca nt generate enough heat in this cold vacuum of a comedy to start a reaction .
#  Saved: so much like a young robert deniro
#  Saved: khouri manages  with terrific flair  to keep the extremes of screwball farce and bloodcurdling family intensity on one continuum .
#  Saved: fashioning an engrossing entertainment out
#  Saved: spiffy animated feature
#  Saved: that s so sloppily written and cast that you can not believe anyone more central to the creation of bugsy than the caterer
#  Saved: alternating between facetious comic parody and pulp melodrama  this smartaleck movie ... tosses around some intriguing questions about the difference between human and android life
#  Saved: strungtogether moments
#  Saved: generous and subversive artworks
#  Saved: it does nt follow the stale  standard  connectthedots storyline which has become commonplace in movies that explore the seamy underbelly of the criminal world
#  Saved: funny yet
#  Saved: overbearing and overthetop
#  Saved: it s robert duvall !
#  Saved: rich and sudden wisdom
#  Saved: acted and directed  it s clear that washington most certainly has a new career ahead of him
#  Saved: in memory
#  Saved: respectable new one
#  Saved: yet this grating showcase
#  Saved: hate to tear your eyes away from the images long enough to read the subtitles
#  Saved: addition to sporting one of the worst titles in recent cinematic history
#  Saved: this genderbending comedy is generally quite funny .
#  Saved: build some robots  haul em to the theater with you for the late show  and put on your own mystery science theatre 3000 tribute to what is almost certainly going to go down as the worst  and only  killer website movie of this or any other year
#  Saved: do nt work in concert
#  Saved: the direction has a fluid  nononsense authority  and the performances by harris  phifer and cam  ron seal the deal .
#  Saved: would have liked it more if it had just gone that one step further
#  Saved: it s too harsh to work as a piece of storytelling
#  Saved: hawaiian shirt
#  Saved: takes a classic story  casts attractive and talented actors and uses a magnificent landscape to create a feature film that is wickedly fun to watch .
#  Saved: provide its keenest pleasures
#  Saved: altogether too slight to be called any kind of masterpiece
#  Saved: grievous but
#  Saved: after you laugh once  maybe twice   you will have completely forgotten the movie by the time you get back to your car in the parking lot .
#  Saved: hopeless
#  Saved: unpretentious  charming  quirky  original
#  Saved: nicks and steinberg match their own creations for pure venality  that s giving it the old college try .
#  Saved: very wellwritten and very wellacted .
#  Saved: are nt many conclusive answers in the film
#  Saved: clumsy dialogue  heavyhanded phoneyfeeling sentiment
#  Saved: proves a lovely trifle that  unfortunately  is a little too in love with its own cuteness .
#  Saved: bring tissues .
#  Saved: the film s midtolow budget is betrayed by the surprisingly shoddy makeup work .
#  Saved: brings the proper conviction to his role as  jason bourne  .
#  Saved: as a young woman of great charm  generosity and diplomacy
#  Saved: there s something poignant about an artist of 90plus years taking the effort to share his impressions of life and loss and time and art with us .
#  Saved: just too silly
#  Saved: cinematic bon bons
#  Saved: it is supremely unfunny and unentertaining to watch middleage and
#  Saved: a lively and engaging examination of how similar obsessions can dominate a family .
#  Saved: irritates and
#  Saved: collapse
#  Saved: so many of the challenges it poses for itself that one can forgive the film its flaws
#  Saved: it serves as a workable primer for the region s recent history  and would make a terrific 10thgrade learning tool .
#  Saved: wideawake all the way through
#  Saved: vainly  i think
#  Saved: is one big excuse to play one lewd scene after another .
#  Saved: is effective if you stick with it
#  Saved: that underscore the importance of family tradition and familial community
#  Saved: delivers what it promises  a look at the  wild ride  that ensues when brash young men set out to conquer the online world with laptops  cell phones and sketchy business plans
#  Saved: watching this digitaleffectsheavy  supposed familyfriendly comedy
#  Saved: absolutely and completely ridiculous and
#  Saved: s a very tasteful rock and roll movie .
#  Saved: the movie is almost completely lacking in suspense  surprise and consistent emotional conviction .
#  Saved: realistic portrayal
#  Saved: as if trying to grab a lump of playdoh  the harder that liman tries to squeeze his story
#  Saved: wellthought stunts or
#  Saved: reveals how important our special talents can be when put in service of of others .
#  Saved: no lika da
#  Saved: a welcome relief
#  Saved: the promise of digital filmmaking
#  Saved: just one that could easily wait for your pay per view dollar
#  Saved: justify a theatrical simulation of the death camp of auschwitz iibirkenau
#  Saved: extraordinary faith
#  Saved: have i seen a film so willing to champion the fallibility of the human heart
#  Saved: sometimes beautiful adaptation
#  Saved: about as interesting
#  Saved: caruso sometimes descends into subtarantino cuteness ... but for the most part he makes sure the salton sea works the way a good noir should  keeping it tight and nasty .
#  Saved: overlong  and bombastic
#  Saved: derivative and hammily
#  Saved: most audacious  outrageous
#  Saved: at its best moments
#  Saved: disney again ransacks its archives for a quickbuck sequel .
#  Saved: that final  beautiful scene
#  Saved: some movies suck you in despite their flaws
#  Saved: eats  meddles  argues  laughs  kibbitzes and fights
#  Saved: the problem with the film is whether these ambitions  laudable in themselves  justify a theatrical simulation of the death camp of auschwitz iibirkenau .
#  Saved: compelling
#  Saved: infectiously
#  Saved: the picture runs a mere 84 minutes  but it s no glance .
#  Saved: think of this dog of a movie
#  Saved: s remarkable procession of sweeping pictures that have reinvigorated the romance genre .
#  Saved: those soso films that could have been much better
#  Saved: a passable date film
#  Saved: imax in short
#  Saved: i hate it .
#  Saved: s pleasant enough  and oozing with attractive men
#  Saved: no one involved  save dash  shows the slightest aptitude for acting
#  Saved: in this wildly uneven movie
#  Saved: pokes  provokes  takes expressionistic license
#  Saved: like one of  spears   music videos in content  except that it goes on for at least 90 more minutes and  worse  that you have to pay if you want to see it
#  Saved: with color and depth  and rather a good time
#  Saved: silly  outrageous  ingenious
#  Saved: being able to hit on a 15year old when you re over 100
#  Saved: the story of trouble every day ... is so sketchy it amounts to little more than preliminary notes for a sciencefiction horror film  and the movie s fragmentary narrative style makes piecing the story together frustrating difficult .
#  Saved: the year s best and most unpredictable comedy
#  Saved: starts off so bad that you feel like running out screaming
#  Saved: men in black ii achieves ultimate insignificance  it s the scifi comedy spectacle as whiffleball epic .
#  Saved: elvira fans could hardly ask for more .
#  Saved: a good one
#  Saved: plodding picture
#  Saved: the character dramas  which never reach satisfying conclusions
#  Saved: lost in the translation this time
#  Saved: speak for it while it forces you to ponder anew what a movie can be
#  Saved: enables shafer to navigate spaces both large ... and small ... with considerable aplomb
#  Saved: a plot cobbled together from largely flat and uncreative moments
#  Saved: inane and awful
#  Saved: told in scattered fashion
#  Saved: takes chances that are bold by studio standards
#  Saved: believe it or not  jason actually takes a backseat in his own film to special effects
#  Saved: only thing to fear about  fear dot com
#  Saved: whole mess
#  Saved: manages to infuse the rocky path to sibling reconciliation with flashes of warmth and gentle humor
#  Saved: working from a surprisingly sensitive script cowritten by gianni romoli ... ozpetek avoids most of the pitfalls you d expect in such a potentially sudsy setup .
#  Saved: a rsum loaded with credits like  girl in bar  3
#  Saved: enjoy the ride
#  Saved: very little to add beyond the dark visions already relayed by superb recent predecessors
#  Saved: the  yes  snaillike pacing
#  Saved: an extremely unpleasant film .
#  Saved: if it is nt entirely persuasive  it does give exposure to some talented performers
#  Saved: the whole affair  true story or not  feels incredibly hokey ...
#  Saved: are all things we ve seen before
#  Saved: poignant and leavened
#  Saved: breathless anticipation
#  Saved: significantly better
#  Saved: as predictable as the tides
#  Saved: bewilderingly brilliant and entertaining
#  Saved: it s smooth and professional
#  Saved: unassuming  subordinate
#  Saved: the horror
#  Saved: a technically superb film
#  Saved: the positive change in tone here seems to have recharged him .
#  Saved: pays earnest homage to turntablists and beat jugglers  old schoolers and current innovators
#  Saved: a dim
#  Saved: vicious and absurd
#  Saved: because he acts so goofy all the time
#  Saved: to a kinetic life so teeming that even cranky adults may rediscover the quivering kid inside
#  Saved: s at once laughable and compulsively watchable
#  Saved: merit its 103minute length
#  Saved: the value and respect for the term epic cinema
#  Saved: as a dentist s waiting room
#  Saved: showing honest emotions
#  Saved: amazingly lame .
#  Saved: confessions may not be a straightforward bio
#  Saved: seems a disappointingly thin slice of lowerclass london life  despite the title ... amounts to surprisingly little
#  Saved: the story is bogus and
#  Saved: this comic gem is as delightful as it is derivative .
#  Saved: to spare wildlife
#  Saved: ugly as the shabby digital photography
#  Saved: understand the difference between dumb fun and just plain dumb
#  Saved: traditionally structured
#  Saved: frida is nt that much different from many a hollywood romance .
#  Saved: does point the way for adventurous indian filmmakers toward a crossover into nonethnic markets .
#  Saved: are worth the price of admission ... if  gory mayhem  is your idea of a good time
#  Saved: was produced by jerry bruckheimer and directed by joel schumacher  and reflects the worst of their shallow styles  wildly overproduced  inadequately motivated every step of the way and demographically targeted to please every one  and no one
#  Saved: carnage and
#  Saved: degraded  handheld blair witch videocam footage
#  Saved: second fiddle
#  Saved: about the folly of superficiality that is itself
#  Saved: serves as autocritique  and its clumsiness as its own most damning censure .
#  Saved: tedious norwegian offering which somehow snagged an oscar nomination .
#  Saved: esther kahn is unusual but unfortunately also irritating .
#  Saved: a stylish exercise
#  Saved: halfway through this picture i was beginning to hate it
#  Saved: a setup so easy it borders on facile
#  Saved: a thoroughly awful movie
#  Saved: takes hold and grips hard
#  Saved: look smeary and blurry  to the point of distraction
#  Saved: the picture s fascinating byways
#  Saved: guns  cheatfully filmed martial arts  disintegrating bloodsucker computer effects and jagged camera moves
#  Saved: breezy  distracted rhythms
#  Saved: than this mess
#  Saved: evanescent  seamless and sumptuous stream
#  Saved: slick and manufactured to claim street credibility .
#  Saved: take care is nicely performed by a quintet of actresses
#  Saved: valuable messages
#  Saved: in no small part thanks to lau
#  Saved: two guys who desperately want to be quentin tarantino when they grow up
#  Saved: no new plot conceptions
#  Saved: essentially a collection of bits
#  Saved: does nt bode well for the rest of it
#  Saved: elevated by it  the kind of movie
#  Saved: usual worst
#  Saved: hugh grant  who has a good line in charm
#  Saved: arrive early and stay late
#  Saved: is a panamerican movie  with moments of genuine insight into the urban heart .
#  Saved: i could have used my two hours better watching being john malkovich again .
#  Saved: shot in artful  watery tones of blue  green and brown
#  Saved: an unorthodox little film noir organized crime story that includes one of the strangest
#  Saved: considerable aplomb
#  Saved: acted by diane lane and richard gere .
#  Saved: scant
#  Saved: an admittedly middling film
#  Saved: too ludicrous
#  Saved: the rock s fighting skills are more in line with steven seagal
#  Saved: rich and full
#  Saved: warm water under a red bridge is a celebration of feminine energy  a tribute to the power of women to heal .
#  Saved: that uses a sensational  reallife 19thcentury crime as a metaphor for
#  Saved: home movie will leave you wanting more  not to mention leaving you with some laughs and a smile on your face .
#  Saved: the film retains ambiguities that make it well worth watching .
#  Saved: ultracheesy dialogue
#  Saved: added depth and resonance
#  Saved: the sensational
#  Saved: hugescreen format to make an oldfashioned nature film that educates viewers with words and pictures while entertaining them
#  Saved: handsome but unfulfilling suspense drama
#  Saved: s not very good either .
#  Saved: in her most charmless
#  Saved: makes an unusual but pleasantly haunting debut behind the camera .
#  Saved: a fine  rousing  grated family film  aimed mainly at little kids but with plenty of entertainment value to keep grownups from squirming in their seats .
#  Saved: everything about girls ca nt swim  even its passages of sensitive observation  feels secondhand  familiar  and not in a good way .
#  Saved: the cast is spot on and
#  Saved: ugly digital video
#  Saved: can only love the players it brings to the fore for the gifted but nononsense human beings they are and for the stillinestimable contribution they have made to our shared history
#  Saved: rather choppy
#  Saved: becomes one more dumb high school comedy about sex gags and prom dates
#  Saved: demands and receives excellent performances
#  Saved: xxx is a blast of adrenalin
#  Saved: pure escapism
#  Saved: create a film that s not merely about kicking undead
#  Saved: about love and culture
#  Saved: is worse
#  Saved: horrifying
#  Saved: mourns her tragedies in private
#  Saved: the action scenes are poorly delivered
#  Saved: it s so bad
#  Saved: so bad
#  Saved: 84 minutes is short
#  Saved: dabbles all around  never gaining much momentum
#  Saved: a masterpiece
#  Saved: a lot to do with the casting of juliette binoche as sand  who brings to the role her pale  dark beauty and characteristic warmth
#  Saved: does nt leave you with much .
#  Saved: good acting
#  Saved: like most of jaglom s films  some of it is honestly affecting
#  Saved: marivaux s rhythms  and mira sorvino s limitations as a classical actress
#  Saved: is less successful on other levels
#  Saved: s still quite worth seeing
#  Saved: intelligent and moving .
#  Saved: he appears miserable throughout as he swaggers through his scenes
#  Saved: men
#  Saved: accomplish what few sequels can
#  Saved: a clunky tvmovie approach to detailing a chapter in the life of the celebrated irish playwright  poet and drinker
#  Saved: i m not sure which half of dragonfly is worse  the part where nothing s happening  or the part where something s happening
#  Saved: exhilarating  funny and fun .
#  Saved: bound to appeal to women looking for a howlingly trashy time
#  Saved: it never quite makes the grade as tawdry trash .
#  Saved: has the right stuff for silly summer entertainment and has enough laughs to sustain interest to the end .
#  Saved: endearing  caring
#  Saved: seagal  who looks more like danny aiello these days
#  Saved: enactments  however fascinating they may be as history  are too crude to serve the work especially well .
#  Saved: not everything in this ambitious comic escapade works  but coppola  along with his sister  sofia  is a real filmmaker
#  Saved: the dehumanizing and egodestroying process
#  Saved: taboo subject matter
#  Saved: see this
#  Saved: utterly incompetent conclusion
#  Saved: has always been part of for the most part wilde s droll whimsy helps  being earnest  overcome its weaknesses and parker s creative interference ...
#  Saved: you find yourself rooting for gai s character to avoid the fate that has befallen every other carmen before her
#  Saved: run for cover
#  Saved: low budget
#  Saved: a deceptively casual ode
#  Saved: walked out muttering words like  horrible  and  terrible
#  Saved: help chicago make the transition from stage to screen with considerable appeal intact
#  Saved: you have ellen pompeo sitting next to you for the ride
#  Saved: a giant step backward
#  Saved: true fans
#  Saved: just copies
#  Saved: quite rich and exciting
#  Saved: luminous interviews and amazingly evocative film from three decades ago
#  Saved: from lynch  jeunet  and von trier while failing to find a spark of its own
#  Saved: you ca nt help but get caught up in the thrill of the company s astonishing growth .
#  Saved: this frozen tundra soap opera
#  Saved: a showdown
#  Saved: is simply too overdone
#  Saved: greatly
#  Saved: free
#  Saved: intriguing species
#  Saved: try and evade
#  Saved: scherfig  who has had a successful career in tv
#  Saved: watching it leaves you giddy
#  Saved: beautifully acted and directed  it s clear that washington most certainly has a new career ahead of him if he so chooses .
#  Saved: far tamer
#  Saved: outrageously creative action
#  Saved: the most purely enjoyable and satisfying evenings
#  Saved: is never any question of how things will turn out
#  Saved: only open new wounds
#  Saved: despite suffering a senseofhumour failure
#  Saved: for a story
#  Saved: in addition to hoffman s powerful acting clinic
#  Saved: right stuff
#  Saved: the wonderful cinematography and naturalistic acting
#  Saved: highconcept films
#  Saved: sleepwalk through vulgarities in a sequel you can refuse
#  Saved: with no reason for being
#  Saved: just about all of the film is confusing on one level or another  making ararat far more demanding than it needs to be .
#  Saved: invigorating  surreal  and resonant
#  Saved: the chateau  a sense of lightheartedness  that makes it attractive throughout
#  Saved: have a passion for the material
#  Saved: maybe it is formula filmmaking  but there s nothing wrong with that if the film is wellcrafted and this one is .
#  Saved: a movie that ca nt get sufficient distance from leroy s
#  Saved: romanticized rendering
#  Saved: is terrific as rachel
#  Saved: of special effects that run the gamut from cheesy to cheesier to cheesiest
#  Saved: the worst film a man has made about women since valley of the dolls
#  Saved: come  already having been recycled more times than i d care to count
#  Saved: with awe
#  Saved: joyous romp of a film .
#  Saved: a nonstop hoot
#  Saved: partisans and sabotage
#  Saved: gory as the scenes of torture and selfmutilation
#  Saved: just as the recent argentine film son of the bride reminded us that a feelgood movie can still show real heart
#  Saved: ub equally spoofs and celebrates the more outre aspects of  black culture  and the dorkier aspects of  white culture   even as it points out how inseparable the two are .
#  Saved: the package in which this fascinating  and timely  content comes wrapped is disappointingly generic .
#  Saved: this obscenely bad dark comedy  so crass
#  Saved: naomi watts is terrific as rachel  her petite frame and vulnerable persona emphasising her plight and isolation
#  Saved: exciting and
#  Saved: schticky
#  Saved: and in the best way
#  Saved: of our most flamboyant female comics
#  Saved: squareness that would make it the darling of many a kidsandfamilyoriented cable channel
#  Saved: less a movie than  an appalling  odoriferous thing ... so
#  Saved: this film special
#  Saved: of the amazing spiderman
#  Saved: the stomachturning violence
#  Saved: could use a little more humanity
#  Saved: not everything
#  Saved: acquires an undeniable entertainment value as the slight  pale mr. broomfield continues to force himself on people and into situations that would make lesser men run for cover .
#  Saved: a slowmoving policeprocedural thriller
#  Saved: a bad idea from frame one
#  Saved: terrific  sweatypalmed fun
#  Saved: very funny joke
#  Saved: volletta wallace s maternal fury
#  Saved: complex story
#  Saved: atop wooden dialogue
#  Saved: that it progresses in such a lowkey manner that it risks monotony
#  Saved: be burns s strongest film since the brothers mcmullen
#  Saved: ca nt miss it
#  Saved: dover kosashvili s outstanding feature debut so potent
#  Saved: of the best short story writing
#  Saved: it seeks excitement in manufactured high drama
#  Saved: feeble comedy .
#  Saved: an insult to every family
#  Saved: it is essentially empty
#  Saved: of the film s problems
#  Saved: makes my big fat greek wedding look like an apartheid drama
#  Saved: is not even half the interest .
#  Saved: never achieve the popularity of my big fat greek wedding
#  Saved: auto focus  works as an unusual biopic and document of male swingers in the playboy era
#  Saved: right now  they re merely signposts marking the slow  lingering death of imagination .
#  Saved: appealing character quirks to forgive that still serious problem
#  Saved: often lingers just as long on the irrelevant as on the engaging  which gradually turns what time is it there ?
#  Saved: the energy it takes to describe how bad it is
#  Saved: wait to see it then .
#  Saved: could easily be called the best korean film of 2002
#  Saved: largestever historical canvas
#  Saved: a solid cast  assured direction and complete lack of modern day irony .
#  Saved: comatose ballerinas
#  Saved: ohsoimportant
#  Saved: of the road  where the thematic ironies are too obvious and the sexual politics too smug
#  Saved: formulaic equations
#  Saved: s a work that  with humor  warmth  and intelligence  captures a life interestingly lived
#  Saved: deserve a passing grade
#  Saved: you re gon na like this movie .
#  Saved: simply stupid  irrelevant
#  Saved: weaves both the elements of the plot and a powerfully evocative mood combining heated sexuality with a haunting sense of malaise .
#  Saved: a heavyhanded indictment of parental failings and
#  Saved: felt performances across the board .
#  Saved: seem weird and distanced
#  Saved: has finally made a movie that is nt just offensive
#  Saved: casual and fun
#  Saved: plodding mess
#  Saved: the weird thing about the santa clause 2  purportedly a children s movie  is that there is nothing in it to engage children emotionally .
#  Saved: the film s intimate camera work
#  Saved: you ll find yourself wishing that you and they were in another movie .
#  Saved: of dishonesty
#  Saved: as bestial
#  Saved: as it is a loose collection of notsofunny gags  scattered moments of lazy humor
#  Saved: they prove more distressing than suspenseful .
#  Saved: crackles
#  Saved: a fairly revealing study of its two main characters
#  Saved: high drama  disneystyle
#  Saved: may be more genial than ingenious  but it gets the job done .
#  Saved: good action  good acting  good dialogue  good pace  good cinematography .
#  Saved: her bully of a husband
#  Saved: gaghan ... has thrown every suspenseful clich in the book at this nonsensical story .
#  Saved: the darker elements of misogyny and unprovoked violence suffocate the illumination created by the two daughters
#  Saved: oozing  chilling and heartwarming
#  Saved: stale retread
#  Saved: filming the teeming life on the reefs
#  Saved: an already thin story boils down to surviving invaders seeking an existent antivirus .
#  Saved: quite endearing .
#  Saved: with fewer gags to break the tedium
#  Saved: overbearing and
#  Saved: deep deceptions
#  Saved: things will turn out okay
#  Saved: the paranoid claustrophobia of a submarine movie with the unsettling spookiness of the supernatural
#  Saved: grand
#  Saved: goodnatured fun found in films like tremors
#  Saved: betters it
#  Saved: transfixes the audience
#  Saved: moving and important
#  Saved: dope
#  Saved: an avid interest
#  Saved: blessed with two fine  nuanced lead performances
#  Saved: true star
#  Saved: hampered  no  paralyzed  by a selfindulgent script ...
#  Saved: is expressly for idiots who do nt care what kind of sewage they shovel into their mental gullets to simulate sustenance .
#  Saved: is haunting ...  it s  what punk rock music used to be  and what the video medium could use more of  spirit  perception  conviction
#  Saved: which nurses plot holes gaping enough to pilot an entire olympic swim team through
#  Saved: Amrozi accused his brother  whom he called  the witness   of deliberately distorting his evidence .
#  Saved: Yucaipa owned Dominick s before selling the chain to Safeway in 1998 for  2.5 billion .
#  Saved: They had published an advertisement on the Internet on June 10  offering the cargo for sale  he added .
#  Saved: Around 0335 GMT  Tab shares were up 19 cents  or 4.4   at A  4.56  having earlier set a record high of A  4.57 .
#  Saved: The stock rose  2.11  or about 11 percent  to close Friday at  21.51 on the New York Stock Exchange .
#  Saved: Revenue in the first quarter of the year dropped 15 percent from the same period a year earlier .
#  Saved: The Nasdaq had a weekly gain of 17.27  or 1.2 percent  closing at 1520.15 on Friday .
#  Saved: The DVDCCA then appealed to the state Supreme Court .
#  Saved: That compared with  35.18 million  or 24 cents per share  in the yearago period .
#  Saved: Shares of Genentech  a much larger company with several products on the market  rose more than 2 percent .
#  Saved: Legislation making it harder for consumers to erase their debts in bankruptcy court won overwhelming House approval in March .
#  Saved: The Nasdaq composite index increased 10.73  or 0.7 percent  to 1514.77 .
#  Saved: But he added group performance would improve in the second half of the year and beyond .
#  Saved: He told The Sun newspaper that Mr. Hussein s daughters had British schools and hospitals in mind when they decided to ask for asylum .
#  Saved: Gyorgy Heizler  head of the local disaster unit  said the coach was carrying 38 passengers .
#  Saved: Show me veggie restaurants nearby
#  Saved: Find me a salad bar I can go to for my lunch meeting
#  Saved: Whats the best irish pub in hells kitchen?
#  Saved: Find a store near Sias place where I can buy champagne
#  Saved: Is there a place similar to Per Se in Williamsburg?
#  Saved: Find the top 3 family attractions in Hollywood not far from Angies place
#  Saved: Find the best restaurants near my airbnb that serve brunch all day
#  Saved: Find me a romantic restaurant that serves good expensive wine near my girlfriends work
#  Saved: Show me the best museums to visit near my London your stay
#  Saved: Find me a brunch spot in Lower Manhattan
#  Saved: Find me a coffee place similar to Starbucks that has gluten free food
#  Saved: Find me the cheapest seafood restaurant near the Golden Bridge
#  Saved: Find me a place that sells burritos in South Harlem
#  Saved: What are the fanciest clubs in New York?
#  Saved: Where is the nearest Starbucks?
#  Saved: Find me a good expensive japanese restaurant near work
#  Saved: Find a good fried chicken restaurant that is not a fast food
#  Saved: Find me the closest theatre for tonight
#  Saved: Show me the parks with swings and pony rides around my aunts place
#  Saved: Find me the finest sushi restaurant in the area of my next meeting
#  Saved: Find me a table for four for dinner tonight
#  Saved: Book a table for todays lunch at Eggys Diner for 3 people
#  Saved: Book a table at a restaurant near Times Square for 2 people tomorrow night
#  Saved: Book a table for friday 8pm for 2 people at Katzs Delicatessen
#  Saved: Book a table at Joans on Third for my family reunion on Saturday
#  Saved: Id like a table in a peaceful restaurant around Times Square
#  Saved: Book a table at Seven Hills for 6 people with a nice view
#  Saved: Book a table for 6 people at Mr Donahues for tomorrows lunch
#  Saved: Book a restaurant for 6 near my morning meeting tomorrow at 1pm
#  Saved: I want reservations to grab brunch for 5 in hells kitchen tomorrow
#  Saved: Book a table for Sophie and me at the Red Lobster tonight
#  Saved: Book a table for 3 people at a restaurant that serve tapas and wine for tonight
#  Saved: Book a table near my London hotel next Wednesday evening
#  Saved: Book me a table for 845pm at a restaurant with wifi near my your stay
#  Saved: Figure out if I can get a reservation at Ma Peche after the concert
#  Saved: Book a table for four people at Tapestry for 9pm tonight
#  Saved: Get me a spot at Ippudo for lunch
#  Saved: Book a table at the best chinese restaurant in town for todays lunch
#  Saved: Book a restaurant for brunch next Sunday
#  Saved: Book me a table for 2 people at the sushi place next to the show tomorrow night
#  Saved: Make a reservation for 4 people for todays lunch at Daniel
#  Saved: Book a table for four people at Mondrian Soho for 8pm
#  Saved: Get me a table at Din Tai Fung for the 4th of December at 1230
#  Saved: Get me a table at a restaurant nearby that is not too crowded for tomorrow evening
#  Saved: Find me an outdoor table at Five leaves for 3
#  Saved: Get me a table at Delmonicos next monday at 8pm
#  Saved: We are a party of 4 people and we want to book a table at Seven Hills for sunset
#  Saved: I need reservations at Quince at 930
#  Saved: Make a reservation at Delmonicos on Saturday 8pm for 10 people
#  Saved: Book a table at an italian restaurant nearby for dinner with 5 people
#  Saved: Book a table at the nearest sushi restaurant for 2 for 1pm
#  Saved: Book me a table for 4 at Delmonicos around 8pm this friday
#  Saved: Is there a table for boozy brunch at around 11 nearby?
#  Saved: Need a table for lunch to eat steak near penn station
#  Saved: Get me a table at a restaurant near Emilys place for tomorrow 9pm
#  Saved: Book a table for 5 people at the restaurant Im used to going to every week
#  Saved: Make a reservation for breakfast at Batter  Berries tomorrow
#  Saved: Get me a place near chelsea with good brunch cocktails tomorrow at 10
#  Saved: Book a table for two people at a restaurant near work
#  Saved: Table for a group of 12 near west village tomorrow? go!
#  Saved: I want a reservation for 5 at Alinea
#  Saved: Make a reservation for 4 people for todays lunch at a Starbucks nearby
#  Saved: Get me a table at a good deli near Mission Dolores Park for lunch
#  Saved: Please book a table at Delmonicos this evening for 3 at 8pm
#  Saved: I need a reservation for five people at Galli for friday night
#  Saved: Can you make a reservation at a lebanese restaurant nearby for lunch party of 5?
#  Saved: See if theres a table outside for noon at that fried chicken restaurant I like
#  Saved: Book a table at Chops Lobster Bar for 5 people at 730pm
#  Saved: I want to find a reservation at an old red sauce joint at 6
#  Saved: Book a table for 3 people at the restaurant I went to last week
#  Saved: Make a reservation for 3 at the finest restaurant in the area where I was yesterday afternoon
#  Saved: I want a table in a good japanese restaurant near Trump tower
#  Saved: Table for two at Nobu New York tonight
#  Saved: Book a table at The Standard Grill for four people for the day after tomorrow at 830pm
#  Saved: Book for 4 people at Per Se for Tuesday evening
#  Saved: I want a table for friday 8pm for 2 people at Katzs Delicatessen
#  Saved: Need a table for 6
#  Saved: I want a reservation to get drinks after class tomorrow for 10
#  Saved: Book a table at an American restaurant for Thanksgiving
#  Saved: Book a table at Galli for 6 people tonight
#  Saved: Book for 4 at Nobu for tomorrow evening
#  Saved: Book a table for four people at La Chine for the 11th at 8pm
#  Saved: Book a table at Saddle Peak Lodge for my diner with friends tonight
#  Saved: Can I have a table at the Russian Tea Room for 4pm?
#  Saved: Book a table for 8 at Tavern on the Green for 8 pm
#  Saved: Need a table for 12 in 3 hours
#  Saved: Book a table for me and my girlfriend in a romantic restaurant for Valentines day
#  Saved: Need a reservation for brunch for 5 in williamsburg near the bridge
#  Saved: Book me and my sister a spot at the milk bar place near the hotel she stays at in midtown
#  Saved: Book me a table for 4 at Delmonicos
#  Saved: Get a taxi to Emmits Irish Pub
#  Saved: Get me a ride to the airport
#  Saved: Order a taxi for tomorrow 8am
#  Saved: Get a cab at my place right now
#  Saved: Order a taxi
#  Saved: I need a taxi for 6 to go to Audrey and Sams wedding
#  Saved: Book an Uber to my next meeting
#  Saved: I need a taxi to catch my flight tomorrow morning
#  Saved: Book a cab
#  Saved: Book a taxi to go to Sebastians
#  Saved: Find a taxi
#  Saved: I need a cab to go to work
#  Saved: I need a taxi in 5 minutes at 36 5th avenue
#  Saved: Book an Uber to home
#  Saved: Can you find me a ride at this hour?
#  Saved: Order a cab for 6 people
#  Saved: I need an Uber right now
#  Saved: Book me a ride at my current location
#  Saved: Order a cab at my mothers place to go to the LA stadium
#  Saved: Get an Uber to go to my dinner tonight
#  Saved: Book a Lyft car to go to 33 greene street
#  Saved: I want a taxi right now
#  Saved: Is there any Uber around?
#  Saved: Get a taxi to the nearest japanese restaurant
#  Saved: Order a cab at Shake Shack to go to the Empire State Building
#  Saved: Get a Lyft car at Scotts place
#  Saved: How do I go to Montauk avoiding tolls?
#  Saved: Directions to Disneyworld avoiding traffic
#  Saved: Show me the way to go to 33 Greene Street
#  Saved: Give me directions to my parents place avoiding toll roads
#  Saved: Show me directions to my next meeting avoiding traffic
#  Saved: Quickest directions to go pick up my son at soccer practice
#  Saved: Show me directions to my yoga retreat avoiding the highway
#  Saved: Bicycling directions to Millenium park
#  Saved: Directions to La Guardia airport using Waze
#  Saved: Cycling directions to Chelsea Market
#  Saved: Cycling directions to my surf lesson at 10am
#  Saved: Show me the fastest itinerary to my your stay on a Friday night
#  Saved: Driving directions to Tavern on the Green
#  Saved: Transit directions to Barcelona Wine Bar
#  Saved: Navigate to Palo Alto avoiding traffic
#  Saved: Directions to JFK airport at 7am
#  Saved: How do I go back home?
#  Saved: Walking directions to my Christmas party with Citymapper
#  Saved: Get me directions to Johns place if I leave at 6pm
#  Saved: Walking directions from home to my Halloween party stopping by a wine store
#  Saved: Directions to Tulsa with road 66
#  Saved: Show me the way to go to work
#  Saved: Give me transit directions from Grand Central to Brooklyn bridge
#  Saved: Navigate me to Empire State Building using the shortest way
#  Saved: Show me walking directions to MOMA
#  Saved: Get me directions to Las Vegas avoiding toll roads
#  Saved: Show me directions to Jersey City avoiding the highway
#  Saved: Show me the directions from the LA County Museum to Santa Monica
#  Saved: Directions to my beach house avoiding tolls
#  Saved: Show me directions to my hotel
#  Saved: Show me the fastest itinerary to go to Williamsburg
#  Saved: Fastest way to go to my next meeting
#  Saved: Directions to Joes pub
#  Saved: I want to go to Boston with the quickest itinerary
#  Saved: Show me the way to Rands birthday party by car
#  Saved: Share my ETA with Mary Jane
#  Saved: Send my ETA to the guy Im meeting with
#  Saved: Share my time of arrival with my your stay host
#  Saved: Share my arrival time with Juan Carlos
#  Saved: Share my ETA with Jo
#  Saved: Share my estimated time of arrival with Lily
#  Saved: Send my time of arrival to Nina
#  Saved: Tell my friends what time Ill get there
#  Saved: Share with Franz my ETA
#  Saved: Send a message to John to tell him when I get there
#  Saved: Send my ETA to my girlfriend
#  Saved: Tell Valery how long its gonna take to join her
#  Saved: Share my ETA with the guy who just called me
#  Saved: Share my ETA
#  Saved: Share my ETA with my data scientist
#  Saved: Share my estimated time of arrival with my mother
#  Saved: Send a message to Michael with my ETA
#  Saved: Share my ETA with the Snips team
#  Saved: Send my ETA to the girl Im supposed to have dinner with
#  Saved: Send a message to Montgomery with my arrival time
#  Saved: Send my ETA to the guests of my apartment
#  Saved: Send a message to my boss with my ETA
#  Saved: Should I expect traffic from here to Kennedy international airport?
#  Saved: Any traffic problems to go to my dinner?
#  Saved: Any accidents from my your stay to Golden Gate Bridge?
#  Saved: Is there traffic from work to gym?
#  Saved: Is there traffic on my way to the gym?
#  Saved: Hows traffic to go to my hotel?
#  Saved: Hows the road on the 11th avenue?
#  Saved: I want to know if there is traffic to go to my upcoming meeting
#  Saved: Is there traffic jam on 6th avenue?
#  Saved: Any accidents to expect to go to my cousins place?
#  Saved: Hows the traffic from here to Jo place?
#  Saved: Is there traffic on 8th avenue and west 14th street?
#  Saved: Shoud I expect traffic between broadway and prince street?
#  Saved: Is there traffic on the US 50 portion Im going to take to go to my client meeting?
#  Saved: Are there any accidents from home to work?
#  Saved: Should I expect any traffic to go meet my friends tonight?
#  Saved: Is there traffic jam from here to Brooklyn bridge?
#  Saved: Hows the traffic from here to Central Park?
#  Saved: Is the road to work congested?
#  Saved: Is there any traffic on US 20?
#  Saved: Show me the forecast for New Orleans
#  Saved: Will it be cloudy at my facebook event?
#  Saved: Whats the weather like at my parents?
#  Saved: Is the weather good for a walk today?
#  Saved: Is it cold outside?
#  Saved: Is it going to rain tomorrow?
#  Saved: Whats the weather like at Jo place right now?
#  Saved: Can I walk to my next meeting?
#  Saved: Show me the weather forecast for my upcoming trip to Los Angeles
#  Saved: Will it rain in the next 30 minutes?
#  Saved: Whats the weather like in Paris New York and Chicago?
#  Saved: Whats the weather forecast for the rest of the week?
#  Saved: Whats the weather like from New York to Boston?
#  Saved: How windy will it be tomorrow?
#  Saved: Should I have an umbrella with me tomorrow?
#  Saved: What will the weather be like at Jo place this afternoon?
#  Saved: Can I go hiking this afternoon?
#  Saved: What is the temperature tomorrow morning?
#  Saved: Is it cold outside?
#  Saved: Should I take an umbrella to walk to my dinner?
#  Saved: What will the weather be like from Home to Jo place?
#  Saved: Whats the weather like in 3 days?
#  Saved: What will the weather be like from 8am to 2pm in Central Park?
#  Saved: What will the weather be like tomorrow morning?
#  Saved: Can I take my bike to go to work today?
#  Saved: What will the weather be like in London next week?
#  Saved: Is it windy today?
#  Saved: Whats the weather like at work?
#  Saved: Is it going to be sunny next week?
#  Saved: I want the weather in Paris
#  Saved: It is a beautiful day for a walk?
#  Saved: Whats it like outside?
#  Saved: What will the weather be like when I land in Paris?
#  Saved: Is it raining right now?
#  Saved: What will the weather be like at my your stay this week end?
#  Saved: Whats the weather like in Bordeaux?
#  Saved: Whats the weather like near my upcoming event?
#  Saved: Will it rain tomorrow near my all day event?
#  Saved: I need the weather at Jo place around 8 pm
#  Saved: What will the weather be like when I get out of my afternoon meeting?
#  Saved: Show me the forecast for my upcoming weekend
#  Saved: Should I take a rain coat today?

# %% [markdown]
# ##  Step 2: Load Pre-extracted Features
# Here we load the audio features extracted using Wav2Vec2 for SNIPS, SST-2, and MRPC.

# %%
import torch
import torchaudio
from transformers import Wav2Vec2Model, Wav2Vec2Processor
from tqdm import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-base")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-base").to(device)
model.eval()

def extract_features_from_csv(csv_path, out_path):
    df = pd.read_csv(csv_path)
    features = []
    labels = []

    for i, row in tqdm(df.iterrows(), total=len(df), desc=f"Extracting from {csv_path}"):
        path = row["path"]
        label = row["label"]

        try:
            waveform, sr = torchaudio.load(path)
            waveform = waveform.squeeze(0)

            if sr != 16000:
                waveform = torchaudio.transforms.Resample(sr, 16000)(waveform)

            inputs = processor(waveform, sampling_rate=16000, return_tensors="pt", padding=True)
            with torch.no_grad():
                out = model(inputs.input_values.to(device)).last_hidden_state.mean(dim=1)

            features.append(out.squeeze().cpu())
            labels.append(label)

        except Exception as e:
            print(f" Failed: {path}, error: {e}")

    features = torch.stack(features)
    labels = torch.tensor(labels)

    torch.save({"features": features, "labels": labels}, out_path)
    print(f" Saved: {out_path}")

extract_features_from_csv("metadata_sst2.csv", "features_sst2.pt")
extract_features_from_csv("metadata_mrpc.csv", "features_mrpc.pt")
extract_features_from_csv("metadata_snips.csv", "features_snips.pt")
# Out:
# preprocessor_config.json:   0%|          | 0.00/159 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/163 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.84k [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/transformers/configuration_utils.py:315: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/291 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/380M [00:00<?, ?B/s]
# Extracting from metadata_sst2.csv:   0%|          | 0/500 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/380M [00:00<?, ?B/s]
# Extracting from metadata_sst2.csv: 100%|██████████| 500/500 [00:18<00:00, 26.96it/s]
#  Saved: features_sst2.pt
# Extracting from metadata_mrpc.csv: 100%|██████████| 500/500 [00:32<00:00, 15.26it/s]
#  Saved: features_mrpc.pt
# Extracting from metadata_snips.csv: 100%|██████████| 328/328 [00:09<00:00, 33.07it/s]
#  Saved: features_snips.pt

# %% [markdown]
# ##  Step 3: Prepare PyTorch Dataset + DataLoader

# %%
from torch.utils.data import DataLoader, TensorDataset

def get_dataloader(pt_file, batch_size=32, shuffle=True):
    data = torch.load(pt_file)
    features = data["features"]
    labels = data["labels"]
    dataset = TensorDataset(features, labels)
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=shuffle)
    return loader

train_loader_sst2 = get_dataloader("features_sst2.pt", batch_size=32)
train_loader_mrpc = get_dataloader("features_mrpc.pt", batch_size=32)
train_loader_snips = get_dataloader("features_snips.pt", batch_size=32)

batch = next(iter(train_loader_sst2))
print("SST-2 Sample batch shape:", batch[0].shape, "Labels:", batch[1].shape)
# Out:
# SST-2 Sample batch shape: torch.Size([32, 768]) Labels: torch.Size([32])

# %% [markdown]
# ##  Step 4: Define the DoRA Model
# We define a Decomposed Rank-Adaptive (DoRA) classifier with a low-rank adapter layer.

# %%
import torch.nn as nn

class DoRALinear(nn.Module):
    def __init__(self, in_features, out_features, rank=4):
        super(DoRALinear, self).__init__()
        self.linear = nn.Linear(in_features, out_features)
        self.dora_A = nn.Linear(in_features, rank, bias=False)
        self.dora_B = nn.Linear(rank, out_features, bias=False)

    def forward(self, x):
        return self.linear(x) + self.dora_B(self.dora_A(x))

class DoRAClassifier(nn.Module):
    def __init__(self, input_dim=768, num_classes=2, rank=4, dropout=0.1):
        super(DoRAClassifier, self).__init__()
        self.dropout = nn.Dropout(dropout)
        self.classifier = DoRALinear(input_dim, num_classes, rank)

    def forward(self, x):
        x = self.dropout(x)
        return self.classifier(x)

# %% [markdown]
# ##  Step 5: Load Pre-extracted Features
# Here we load the audio features extracted using Wav2Vec2 for SNIPS, SST-2, and MRPC.

# %%
import torch.nn.functional as F
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

snips_data = torch.load("features_snips.pt")
X = snips_data["features"]
y = snips_data["labels"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

train_loader_snips = DataLoader(TensorDataset(X_train, y_train), batch_size=32, shuffle=True)
test_loader_snips = DataLoader(TensorDataset(X_test, y_test), batch_size=32, shuffle=False)

class DoRALinear(nn.Module):
    def __init__(self, in_features, out_features, rank=16):
        super().__init__()
        self.linear = nn.Linear(in_features, out_features)
        self.dora_A = nn.Linear(in_features, rank, bias=False)
        self.dora_B = nn.Linear(rank, out_features, bias=False)

    def forward(self, x):
        return self.linear(x) + self.dora_B(self.dora_A(x))

class DoRAClassifierImproved(nn.Module):
    def __init__(self, input_dim=768, num_classes=10, rank=16, hidden_dim=256):
        super().__init__()
        self.dropout = nn.Dropout(0.3)
        self.dora1 = DoRALinear(input_dim, hidden_dim, rank)
        self.relu = nn.ReLU()
        self.out = nn.Linear(hidden_dim, num_classes)

    def forward(self, x):
        x = self.dropout(x)
        x = self.relu(self.dora1(x))
        return self.out(x)

model = DoRAClassifierImproved().to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4, weight_decay=1e-2)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=8, gamma=0.5)
criterion = nn.CrossEntropyLoss()

epochs = 20
for epoch in range(epochs):
    model.train()
    total_loss = 0
    all_preds, all_labels = [], []

    for features, labels in train_loader_snips:
        features, labels = features.to(device), labels.to(device)

        logits = model(features)
        loss = criterion(logits, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

    acc = accuracy_score(all_labels, all_preds)
    print(f"Epoch {epoch+1}/{epochs} - Loss: {total_loss:.4f} - Accuracy: {acc:.4f}")
    scheduler.step()
# Out:
# Epoch 1/20 - Loss: 20.3743 - Accuracy: 0.1756
# Epoch 2/20 - Loss: 19.7579 - Accuracy: 0.2137
# Epoch 3/20 - Loss: 19.4022 - Accuracy: 0.2328
# Epoch 4/20 - Loss: 19.5344 - Accuracy: 0.2443
# Epoch 5/20 - Loss: 19.3568 - Accuracy: 0.2366
# Epoch 6/20 - Loss: 19.2508 - Accuracy: 0.2748
# Epoch 7/20 - Loss: 19.0181 - Accuracy: 0.2634
# Epoch 8/20 - Loss: 18.8969 - Accuracy: 0.2863
# Epoch 9/20 - Loss: 18.6463 - Accuracy: 0.3053
# Epoch 10/20 - Loss: 18.3484 - Accuracy: 0.2977
# Epoch 11/20 - Loss: 19.0164 - Accuracy: 0.3053
# Epoch 12/20 - Loss: 18.4555 - Accuracy: 0.3053
# Epoch 13/20 - Loss: 18.2204 - Accuracy: 0.2863
# Epoch 14/20 - Loss: 17.9982 - Accuracy: 0.3206
# Epoch 15/20 - Loss: 18.3907 - Accuracy: 0.3206
# Epoch 16/20 - Loss: 18.1364 - Accuracy: 0.3130
# Epoch 17/20 - Loss: 18.1379 - Accuracy: 0.3321
# Epoch 18/20 - Loss: 17.8394 - Accuracy: 0.3550
# Epoch 19/20 - Loss: 17.8183 - Accuracy: 0.3282
# Epoch 20/20 - Loss: 17.7228 - Accuracy: 0.3359

# %% [markdown]
# ##  Step 6: Create New Classifier Heads for Transfer
# We freeze the encoder and define new heads for SST-2 and MRPC.

# %%
for param in model.dora1.parameters():
    param.requires_grad = False

head_sst2 = nn.Linear(256, 2).to(device)
head_mrpc = nn.Linear(256, 2).to(device)

# %% [markdown]
# ##  Step 7: Train New Head on SST-2

# %%
optimizer_sst2 = torch.optim.AdamW(head_sst2.parameters(), lr=1e-3)
criterion = nn.CrossEntropyLoss()

for epoch in range(10):
    head_sst2.train()
    total_loss, all_preds, all_labels = 0, [], []

    for features, labels in train_loader_sst2:
        features, labels = features.to(device), labels.to(device)
        with torch.no_grad():
            encoded = model.dora1(features)
        logits = head_sst2(encoded)
        loss = criterion(logits, labels)

        optimizer_sst2.zero_grad()
        loss.backward()
        optimizer_sst2.step()

        total_loss += loss.item()
        all_preds.extend(torch.argmax(logits, dim=1).cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

    acc = accuracy_score(all_labels, all_preds)
    print(f"[SST-2] Epoch {epoch+1} - Loss: {total_loss:.4f} - Accuracy: {acc:.4f}")
# Out:
# [SST-2] Epoch 1 - Loss: 11.1505 - Accuracy: 0.4940
# [SST-2] Epoch 2 - Loss: 11.0396 - Accuracy: 0.5460
# [SST-2] Epoch 3 - Loss: 11.0733 - Accuracy: 0.5140
# [SST-2] Epoch 4 - Loss: 11.0424 - Accuracy: 0.5360
# [SST-2] Epoch 5 - Loss: 11.0811 - Accuracy: 0.5140
# [SST-2] Epoch 6 - Loss: 11.0560 - Accuracy: 0.5300
# [SST-2] Epoch 7 - Loss: 11.1782 - Accuracy: 0.4940
# [SST-2] Epoch 8 - Loss: 11.0696 - Accuracy: 0.4940
# [SST-2] Epoch 9 - Loss: 11.0624 - Accuracy: 0.5400
# [SST-2] Epoch 10 - Loss: 11.0132 - Accuracy: 0.5360

# %% [markdown]
# ##  Step 8: Train Classifier on MRPC (Transfer Learning)
# We train a 2-class classifier on MRPC using the same frozen encoder.

# %%
optimizer_mrpc = torch.optim.AdamW(head_mrpc.parameters(), lr=1e-3)

for epoch in range(10):
    head_mrpc.train()
    total_loss, all_preds, all_labels = 0, [], []

    for features, labels in train_loader_mrpc:
        features, labels = features.to(device), labels.to(device)
        with torch.no_grad():
            encoded = model.dora1(features)
        logits = head_mrpc(encoded)
        loss = criterion(logits, labels)

        optimizer_mrpc.zero_grad()
        loss.backward()
        optimizer_mrpc.step()

        total_loss += loss.item()
        all_preds.extend(torch.argmax(logits, dim=1).cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

    acc = accuracy_score(all_labels, all_preds)
    print(f"[MRPC] Epoch {epoch+1} - Loss: {total_loss:.4f} - Accuracy: {acc:.4f}")
# Out:
# [MRPC] Epoch 1 - Loss: 10.2635 - Accuracy: 0.6920
# [MRPC] Epoch 2 - Loss: 10.0245 - Accuracy: 0.6920
# [MRPC] Epoch 3 - Loss: 9.9195 - Accuracy: 0.6920
# [MRPC] Epoch 4 - Loss: 9.8232 - Accuracy: 0.6920
# [MRPC] Epoch 5 - Loss: 9.9436 - Accuracy: 0.6920
# [MRPC] Epoch 6 - Loss: 9.9606 - Accuracy: 0.6920
# [MRPC] Epoch 7 - Loss: 9.8825 - Accuracy: 0.6920
# [MRPC] Epoch 8 - Loss: 9.9738 - Accuracy: 0.6920
# [MRPC] Epoch 9 - Loss: 9.9024 - Accuracy: 0.6920
# [MRPC] Epoch 10 - Loss: 9.8747 - Accuracy: 0.6920
